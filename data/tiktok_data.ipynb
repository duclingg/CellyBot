# %%
import pandas as pd

# %%
with open("followers.txt", "r") as file:
    lines = file.readlines()

# %%
lines = [line.rstrip() for line in lines]

for i in range(len(lines)):
    if lines[i] == '':
        lines[i] = None
        
lines
# Out:
# [None,
#  'GlovoX@Bloodstrike$',
#  'glovox_blodstrike8',
#  None,
#  None,
#  'Evelyn',
#  'wx1drdam5pl',
#  None,
#  None,
#  '💎',
#  'nihh83996',
#  None,
#  None,
#  'NATE on yt',
#  'nathanzuniga0',
#  None,
#  None,
#  'tay_tay3230',
#  'moneytae3',
#  None,
#  None,
#  'Shady',
#  'jett.jones00',
#  None,
#  None,
#  'Ej',
#  '5starquater_back8',
#  None,
#  None,
#  'iloveyou',
#  'stacitolbert3',
#  None,
#  None,
#  'Tj',
#  'tj21961',
#  None,
#  None,
#  'Givonte Warren',
#  'givonte.warren84',
#  None,
#  None,
#  'Finn_breun',
#  'finn_breun',
#  None,
#  None,
#  'Maria King',
#  'maria.king61',
#  None,
#  None,
#  'brysonkemp5',
#  'bryson.kemp52',
#  None,
#  None,
#  'K A Y D E N',
#  'kaylaismygirlfriend0',
#  None,
#  None,
#  'Kaiser',
#  'darkie_at_his_best',
#  None,
#  None,
#  'Reese Brown',
#  'reese.brown61',
#  None,
#  None,
#  'Kin Von',
#  'kkin085',
#  None,
#  None,
#  'jaxonfrancis7_0',
#  'jaxonfrancis7_0',
#  None,
#  None,
#  '420jimmybobjoe',
# ...

# %%
df = pd.DataFrame({'username': lines})
df.dropna(inplace=True)
df.head()
# Out:
#               username
# 1  GlovoX@Bloodstrike$
# 2   glovox_blodstrike8
# 5               Evelyn
# 6          wx1drdam5pl
# 9                    💎

# %%
df = df.iloc[1::2]
df.head()
# Out:
#               username
# 2   glovox_blodstrike8
# 6          wx1drdam5pl
# 10           nihh83996
# 14       nathanzuniga0
# 18           moneytae3
